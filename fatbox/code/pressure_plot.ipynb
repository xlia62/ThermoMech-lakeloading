# %%
#%% import modules 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import h5py 
plt.rcParams.update({'font.size': 18})

# %%
step = 10
path = '/home/lxue07/Documents/aspect/rifting_VE/\
output-test-from-extension_ve_2-pressure-test_constant_hdf5/solution/solution-000'+str(step).zfill(2)+ '.h5'
f_l = h5py.File(path, 'r')
path = '/home/lxue07/Documents/aspect/rifting_VE/\
output-test-from-extension_ve_2-pressure-test_unload_load_hdf5/solution/solution-000'+ str(step).zfill(2)+ '.h5'
f_ul = h5py.File(path, 'r')

print ('output variables:', f_ul.keys())
path_xy = '/home/lxue07/Documents/aspect/rifting_VE/\
output-test-from-extension_ve_2-pressure-test_unload_load_hdf5/solution/mesh-00000.h5'
mesh =h5py.File(path_xy, 'r')
#node in x, y, z
x = mesh['nodes'][:,0]
y = mesh['nodes'][:,1]
xx_ul = f_ul['ve_stress_xx'][:,0]
xx_l = f_l['ve_stress_xx'][:,0]
yy_ul = f_ul['ve_stress_yy'][:,0]
yy_l = f_l['ve_stress_yy'][:,0]

xy_ul = np.sqrt(xx_ul**2 + yy_ul**2)
xy_l = np.sqrt(xx_l**2 + yy_l**2)
# strain_rate = f_ul['strain_rate'][:,0]
# diff_mf = f_ul['melt_fraction'][:,0] - f_l['melt_fraction'][:,0]

# diff_p = f_ul['p'][:,0] - f_l['p'][:,0]
# diff_nonad_p = f_ul['nonadiabatic_pressure'][:,0] - f_l['nonadiabatic_pressure'][:,0]
p_l= f_l['p'][:,0]
p_ul = f_ul['p'][:,0]
# t = f_ul['T'][:,0]
# Out:
# output variables: <KeysViewHDF5 ['T', 'adiabatic_heating', 'compositional_heating', 'crust_lower', 'crust_upper', 'density', 'elastic_shear_modulus', 'latent_heat', 'mantle_lithosphere', 'melt_fraction', 'nonadiabatic_pressure', 'nonadiabatic_temperature', 'p', 'principal_stress_1', 'principal_stress_2', 'principal_stress_direction_1', 'principal_stress_direction_2', 'shear_heating', 'shear_stress_xx', 'shear_stress_xy', 'shear_stress_yx', 'shear_stress_yy', 'strain_rate', 'stress_xx', 'stress_xy', 'stress_yx', 'stress_yy', 've_stress_xx', 've_stress_xy', 've_stress_yy', 'velocity', 'viscosity']>

# %%
fig,ax = plt.subplots(figsize=(12,6))

#ax1 = plt.tricontour(x, y, t, colors=['white'], levels = [500, 900, 1300, 1700])
plt.tricontourf(x, y, xy_l- xy_ul, cmap='RdYlBu_r', levels = 20)
plt.colorbar(label = 'Pressure difference (Pa)')
plt.xlabel('distance (km)')
plt.ylabel('depth (km)')

ax.set_xticks([0, 100000, 200000, 300000])
ax.set_xticklabels([0, 100,200, 300 ])

ax.set_yticks([0, 50000, 100000, 150000, 200000])
ax.set_yticklabels([200, 150,100, 50, 0 ])
#plt.clabel(ax, fontsize=15, inline=1,fmt = '%1.0f')
# Out:
# [Text(0, 0, '200'),
#  Text(0, 50000, '150'),
#  Text(0, 100000, '100'),
#  Text(0, 150000, '50'),
#  Text(0, 200000, '0')]

# %%
fig,ax = plt.subplots(figsize=(12,6))
plt.tricontourf(x, y, p_ul-p_l,cmap='RdYlBu', 
              #  vmax= 1e8, vmin = -1e7, 
                levels = 20
               )
plt.colorbar(label = 'Pressure difference (Pa)')
plt.xlabel('distance (km)')
plt.ylabel('depth (km)')

ax.set_xticks([0, 100000, 200000, 300000])
ax.set_xticklabels([0, 100,200, 300 ])

ax.set_yticks([0, 50000, 100000, 150000, 200000])
ax.set_yticklabels([200, 150,100, 50, 0 ])
# Out:
# [Text(0, 0, '200'),
#  Text(0, 50000, '150'),
#  Text(0, 100000, '100'),
#  Text(0, 150000, '50'),
#  Text(0, 200000, '0')]

# %%
step = 9
path = '/home/lxue07/Documents/aspect/rifting_VE/\
output-test-from-extension_ve_2-pressure-test_constant_hdf5/solution/solution-000'+str(step).zfill(2)+ '.h5'
f_l = h5py.File(path, 'r')
path = '/home/lxue07/Documents/aspect/rifting_VE/\
output-test-from-extension_ve_2-pressure-test_unload_load_hdf5/solution/solution-000'+ str(step).zfill(2)+ '.h5'
f_ul = h5py.File(path, 'r')

print ('output variables:', f_ul.keys())
path_xy = '/home/lxue07/Documents/aspect/rifting_VE/\
output-test-from-extension_ve_2-pressure-test_unload_load_hdf5/solution/mesh-00000.h5'
mesh =h5py.File(path_xy, 'r')
#node in x, y, z
x = mesh['nodes'][:,0]
y = mesh['nodes'][:,1]
xx_ul_9 = f_ul['ve_stress_xx'][:,0]
xx_l_9 = f_l['ve_stress_xx'][:,0]
yy_ul_9 = f_ul['ve_stress_yy'][:,0]
yy_l_9 = f_l['ve_stress_yy'][:,0]

# xy_ul_ = np.sqrt(xx_ul**2 + yy_ul**2)
# xy_l = np.sqrt(xx_l**2 + yy_l**2)
# Out:
# output variables: <KeysViewHDF5 ['T', 'adiabatic_heating', 'compositional_heating', 'crust_lower', 'crust_upper', 'density', 'elastic_shear_modulus', 'latent_heat', 'mantle_lithosphere', 'melt_fraction', 'nonadiabatic_pressure', 'nonadiabatic_temperature', 'p', 'principal_stress_1', 'principal_stress_2', 'principal_stress_direction_1', 'principal_stress_direction_2', 'shear_heating', 'shear_stress_xx', 'shear_stress_xy', 'shear_stress_yx', 'shear_stress_yy', 'strain_rate', 'stress_xx', 'stress_xy', 'stress_yx', 'stress_yy', 've_stress_xx', 've_stress_xy', 've_stress_yy', 'velocity', 'viscosity']>

# %%
step = 8
path = '/home/lxue07/Documents/aspect/rifting_VE/\
output-test-from-extension_ve_2-pressure-test_constant_hdf5/solution/solution-000'+str(step).zfill(2)+ '.h5'
f_l = h5py.File(path, 'r')
path = '/home/lxue07/Documents/aspect/rifting_VE/\
output-test-from-extension_ve_2-pressure-test_unload_load_hdf5/solution/solution-000'+ str(step).zfill(2)+ '.h5'
f_ul = h5py.File(path, 'r')

print ('output variables:', f_ul.keys())
path_xy = '/home/lxue07/Documents/aspect/rifting_VE/\
output-test-from-extension_ve_2-pressure-test_unload_load_hdf5/solution/mesh-00000.h5'
mesh =h5py.File(path_xy, 'r')
#node in x, y, z
x = mesh['nodes'][:,0]
y = mesh['nodes'][:,1]
xx_ul_8 = f_ul['ve_stress_xx'][:,0]
xx_l_8 = f_l['ve_stress_xx'][:,0]
yy_ul_8 = f_ul['ve_stress_yy'][:,0]
yy_l_8 = f_l['ve_stress_yy'][:,0]
# Out:
# output variables: <KeysViewHDF5 ['T', 'adiabatic_heating', 'compositional_heating', 'crust_lower', 'crust_upper', 'density', 'elastic_shear_modulus', 'latent_heat', 'mantle_lithosphere', 'melt_fraction', 'nonadiabatic_pressure', 'nonadiabatic_temperature', 'p', 'principal_stress_1', 'principal_stress_2', 'principal_stress_direction_1', 'principal_stress_direction_2', 'shear_heating', 'shear_stress_xx', 'shear_stress_xy', 'shear_stress_yx', 'shear_stress_yy', 'strain_rate', 'stress_xx', 'stress_xy', 'stress_yx', 'stress_yy', 've_stress_xx', 've_stress_xy', 've_stress_yy', 'velocity', 'viscosity']>

# %%
xy_ul_ = np.sqrt((xx_ul_9-xx_ul_8)**2 + (xx_ul_9-xx_ul_8)**2)
xy_l = np.sqrt((xx_l_9-xx_l_8)**2 + (xx_l_9-xx_l_8)**2)

fig,ax = plt.subplots(figsize=(12,6))

#ax1 = plt.tricontour(x, y, t, colors=['white'], levels = [500, 900, 1300, 1700])
plt.tricontourf(x, y, yy_l_9- yy_l_8,cmap='RdYlBu_r', levels = 20)
plt.colorbar(label = 'Pressure difference (Pa)')
plt.xlabel('distance (km)')
plt.ylabel('depth (km)')

ax.set_xticks([0, 100000, 200000, 300000])
ax.set_xticklabels([0, 100,200, 300 ])

ax.set_yticks([0, 50000, 100000, 150000, 200000])
ax.set_yticklabels([200, 150,100, 50, 0 ])
#plt.clabel(ax, fontsize=15, inline=1,fmt = '%1.0f')
# Out:
# [Text(0, 0, '200'),
#  Text(0, 50000, '150'),
#  Text(0, 100000, '100'),
#  Text(0, 150000, '50'),
#  Text(0, 200000, '0')]
