# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# not Fig. 3
df = pd.read_csv('../AfricaModels2022/Table/\
Lake_drop_restart_71_dry_melting_extract_history_197-253_dt_1_nomark_36_x_0-300_y_0-200.csv')
plt.plot(df['time_ky'], (df['melt_v']-df['melt_refer'])/df['melt_v'])

# test can be done in: drop max 222 and 242, dope min in 232 252

# %%
#SO DRY ONE actually is 1%?
#The not dry one Lake_drop_restart_71_1000m_melting_extract_history_135-203_dt_1_nomark_36_x_0-300_y_0-200

# %%
# now calculate the volume 
df = pd.read_csv('../AfricaModels2022/Table/\
Lake_drop_restart_71_1000m_melting_extract_history_135-203_dt_1_nomark_36_x_0-300_y_0-200.csv')
plt.plot(df['time_ky'], (df['melt_v']-df['melt_refer'])/df['melt_v'])

# test can be done in: drop max 160 and 180, dope min in 170 190

# %%
df['add_melt'] = df['melt_v']-df['melt_refer']
v1 =df.loc[(df['time_ky']>14100) & (df['time_ky']<14200), 'add_melt'].sum()
v2 = df.loc[(df['time_ky']>14200) & (df['time_ky']<14300) , 'add_melt'].sum()
print (v1, v2)
# Out:
# 3.855539556439771 7.803396013221006

# %%
#0.065- 0.34 km^3/kyr in Turkana
print (0.065*50, 0.34*50)
# Out:
# 3.25 17.0

# %%
df = pd.read_csv('../AfricaModels2022/Table/\
Lake_drop_restart_71_1000m_melting_extract_history_362-430_dt_1_nomark_36_x_0-300_y_0-200.csv')
plt.plot(df['time_ky'], (df['melt_v']-df['melt_refer'])/df['melt_v'])

# %%
df = pd.read_csv('../AfricaModels2022/Table/\
Lake_drop_restart_71_1000m_melting_extract_history_367-435_dt_1_nomark_36_x_0-300_y_0-200.csv')
plt.plot(df['time_ky'], (df['melt_v']-df['melt_refer'])/df['melt_v'])

# %%
df = pd.read_csv('../AfricaModels2022/Table/Table/\
Lake_drop_restart_71_1000m_melting_extract_history_135-203_dt_1_nomark_36_x_0-300_y_0-200.csv')
plt.plot(df['time_ky'], (df['melt_v']-df['melt_refer'])/df['melt_v'])

# %%
3.4e24/(7.4e10*3600*24*365.25*1000) #in kyr
# Out:
# 1455.9391698337627

# %%
1e21/(7.4e10*3600*24*365.25)
# Out:
# 428.21740289228313
